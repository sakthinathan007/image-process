# %%
pip install scikit-image

# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.feature import hog
from skimage import data,exposure

# %% [markdown]
# ## Reading Image

# %%
img=cv2.imread("IMG-5.jpg")

# %% [markdown]
# ## HOG

# %%
fd,hog_image=hog(img,orientations=9,pixels_per_cell=(8,8),cells_per_block=(2,2),visualize=True,channel_axis=2)

# %% [markdown]
# ## Rescaling

# %%
rescale=exposure.rescale_intensity(hog_image,in_range=(0,10))

# %% [markdown]
# ## plot

# %%
figure,(a1,a2)=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
a1.axis('off')
a1.imshow(img)
a1.set_title('input image')
a2.axis('off')
a2.imshow(rescale)
a2.set_title('hog_image')
plt.show()

# %%
pip install imutils
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import imutils

# %%
#instalizing the HOG person
hog=cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

#image Reading
img=cv2.imread("people1.jpg")

#Resizing the image
image=imutils.resize(image,width=min(400,img.shape[1]))

#detecting all the regions in the image
(regions,img)=hog.detectMultiScale(image,winStride=(2,2),
                                   padding=(4,4),
                                   scale=1.05)

#Drawing the region in the image
for(x,y,w,h)in regions:
    cv2.rectangle(image,(x,y),
                  (x+w,y+h),
                  (0,255,0),2)
    
#showing the output image
cv2.imshow("image",image)
cv2.waitKey(0)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       6 img=cv2.imread("people1.jpg")
#       8 #Resizing the image
# ----> 9 image=imutils.resize(image,width=min(400,img.shape[1]))
#      11 #detecting all the regions in the image
#      12 (regions,img)=hog.detectMultiScale(image,winStride=(2,2),
#      13                                    padding=(4,4),
#      14                                    scale=1.05)
#
# NameError: name 'image' is not defined
